# %%
from effectiveness import run_temporal_dea
from effectiveness import ( exp1_all_years, exp2_all_years, exp3_all_years, exp4_all_years, exp5_all_years
)

# Experience 1 – Student Enrollment Efficiency
scores_1, names_1 = run_temporal_dea(
    data=exp1_all_years,
    input_vars=['Marketing_Expenses', 'Administratif_Staff'],
    output_vars=['Students'],
    exp_num=1,
    show=False,
    institution_type=1)

# Experience 2 – Research Efficiency
scores_2, names_2 = run_temporal_dea(
    data=exp2_all_years,
    input_vars=['Teaching&Research_Expenses', 'Senior_Staff'],  
    output_vars=['Publications Count', 'Citations Count'],
    exp_num=2,
    show=False,
    institution_type=1)

# Experience 3 – Financial Efficiency
scores_3, names_3 = run_temporal_dea(
    data=exp3_all_years,
    input_vars=['Marketing_Expenses', 'Administratif_Staff'],
    output_vars=['Incomes'],  # <-- vérifier le nom exact
    exp_num=3,
    show=False,
    institution_type=1)

# Experience 4 – Global Performance Efficiency
scores_4, names_4 = run_temporal_dea(
    data=exp4_all_years,
    input_vars=['Marketing_Expenses', 'Administratif_Staff', 'Senior_Staff'],
    output_vars=['Students', 'Citations Count'],
    exp_num=4,
    show=False,
    institution_type=1)

# Experience 5 – Infrastructure Efficiency
scores_5, names_5 = run_temporal_dea(
    data=exp5_all_years,
    input_vars=['Gross Area_2023', 'Administratif_Staff'],
    output_vars=['Publications Count'],
    exp_num=5,
    show=True,
    institution_type=1)
