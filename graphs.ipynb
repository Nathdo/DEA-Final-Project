# %% [markdown]
# # Graphics

# %% [markdown]
# ## 1. Barplots

# %%
import pandas as pd 
import numpy as np
from dealib import dea
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from dea_eff import exp1_2014_uni, exp1_2016_uni, exp1_2021_uni, exp1_2023_uni, exp2_2014_uni, exp2_2016_uni, exp2_2021_uni, exp2_2023_uni
from dea_eff import exp1_2014_col, exp1_2016_col, exp1_2021_col, exp1_2023_col, exp2_2014_col, exp2_2016_col, exp2_2021_col, exp2_2023_col

# Expérience 3
from dea_eff import exp3_2014_uni, exp3_2016_uni, exp3_2021_uni, exp3_2023_uni
from dea_eff import exp3_2014_col, exp3_2016_col, exp3_2021_col, exp3_2023_col

# Expérience 4
from dea_eff import exp4_2014_uni, exp4_2016_uni, exp4_2021_uni, exp4_2023_uni
from dea_eff import exp4_2014_col, exp4_2016_col, exp4_2021_col, exp4_2023_col

# Expérience 5
from dea_eff import exp5_2014_uni, exp5_2016_uni, exp5_2021_uni, exp5_2023_uni
from dea_eff import exp5_2014_col, exp5_2016_col, exp5_2021_col, exp5_2023_col

from build import bar_plot


eff_score_exp1_2014_uni = bar_plot(data = exp1_2014_uni, Institution_ID = 1, year = 2014, exp_num = 1)
eff_score_exp1_2016_uni = bar_plot(data = exp1_2016_uni, Institution_ID = 1, year = 2016, exp_num = 1)
eff_score_exp1_2021_uni = bar_plot(data = exp1_2021_uni, Institution_ID = 1, year = 2021, exp_num = 1)
eff_score_exp1_2023_uni = bar_plot(data = exp1_2023_uni, Institution_ID = 1, year = 2023, exp_num = 1)

eff_score_exp1_2014_col = bar_plot(data = exp1_2014_col, Institution_ID = 2, year = 2014, exp_num = 1)
eff_score_exp1_2016_col = bar_plot(data = exp1_2016_col, Institution_ID = 2, year = 2016, exp_num = 1)
eff_score_exp1_2021_col = bar_plot(data = exp1_2021_col, Institution_ID = 2, year = 2021, exp_num = 1)
eff_score_exp1_2023_col = bar_plot(data = exp1_2023_col, Institution_ID = 2, year = 2023, exp_num = 1)

# Experiment 2
eff_score_exp2_2014_uni = bar_plot(data = exp2_2014_uni, Institution_ID = 1, year = 2014, exp_num = 2)
eff_score_exp2_2016_uni = bar_plot(data = exp2_2016_uni, Institution_ID = 1, year = 2016, exp_num = 2)
eff_score_exp2_2021_uni = bar_plot(data = exp2_2021_uni, Institution_ID = 1, year = 2021, exp_num = 2)
eff_score_exp2_2023_uni = bar_plot(data = exp2_2023_uni, Institution_ID = 1, year = 2023, exp_num = 2)

eff_score_exp2_2014_col = bar_plot(data = exp2_2014_col, Institution_ID = 2, year = 2014, exp_num = 2)
eff_score_exp2_2016_col = bar_plot(data = exp2_2016_col, Institution_ID = 2, year = 2016, exp_num = 2)
eff_score_exp2_2021_col = bar_plot(data = exp2_2021_col, Institution_ID = 2, year = 2021, exp_num = 2)
eff_score_exp2_2023_col = bar_plot(data = exp2_2023_col, Institution_ID = 2, year = 2023, exp_num = 2)

# Experiment 3
eff_score_exp3_2014_uni = bar_plot(data = exp3_2014_uni, Institution_ID = 1, year = 2014, exp_num = 3)
eff_score_exp3_2016_uni = bar_plot(data = exp3_2016_uni, Institution_ID = 1, year = 2016, exp_num = 3)
eff_score_exp3_2021_uni = bar_plot(data = exp3_2021_uni, Institution_ID = 1, year = 2021, exp_num = 3)
eff_score_exp3_2023_uni = bar_plot(data = exp3_2023_uni, Institution_ID = 1, year = 2023, exp_num = 3)

eff_score_exp3_2014_col = bar_plot(data = exp3_2014_col, Institution_ID = 2, year = 2014, exp_num = 3)
eff_score_exp3_2016_col = bar_plot(data = exp3_2016_col, Institution_ID = 2, year = 2016, exp_num = 3)
eff_score_exp3_2021_col = bar_plot(data = exp3_2021_col, Institution_ID = 2, year = 2021, exp_num = 3)
eff_score_exp3_2023_col = bar_plot(data = exp3_2023_col, Institution_ID = 2, year = 2023, exp_num = 3)

# Experiment 4
eff_score_exp4_2014_uni = bar_plot(data = exp4_2014_uni, Institution_ID = 1, year = 2014, exp_num = 4)
eff_score_exp4_2016_uni = bar_plot(data = exp4_2016_uni, Institution_ID = 1, year = 2016, exp_num = 4)
eff_score_exp4_2021_uni = bar_plot(data = exp4_2021_uni, Institution_ID = 1, year = 2021, exp_num = 4)
eff_score_exp4_2023_uni = bar_plot(data = exp4_2023_uni, Institution_ID = 1, year = 2023, exp_num = 4)

eff_score_exp4_2014_col = bar_plot(data = exp4_2014_col, Institution_ID = 2, year = 2014, exp_num = 4)
eff_score_exp4_2016_col = bar_plot(data = exp4_2016_col, Institution_ID = 2, year = 2016, exp_num = 4)
eff_score_exp4_2021_col = bar_plot(data = exp4_2021_col, Institution_ID = 2, year = 2021, exp_num = 4)
eff_score_exp4_2023_col = bar_plot(data = exp4_2023_col, Institution_ID = 2, year = 2023, exp_num = 4)

# Experiment 5
eff_score_exp5_2014_uni = bar_plot(data = exp5_2014_uni, Institution_ID = 1, year = 2014, exp_num = 5)
eff_score_exp5_2016_uni = bar_plot(data = exp5_2016_uni, Institution_ID = 1, year = 2016, exp_num = 5)
eff_score_exp5_2021_uni = bar_plot(data = exp5_2021_uni, Institution_ID = 1, year = 2021, exp_num = 5)
eff_score_exp5_2023_uni = bar_plot(data = exp5_2023_uni, Institution_ID = 1, year = 2023, exp_num = 5)

eff_score_exp5_2014_col = bar_plot(data = exp5_2014_col, Institution_ID = 2, year = 2014, exp_num = 5)
eff_score_exp5_2016_col = bar_plot(data = exp5_2016_col, Institution_ID = 2, year = 2016, exp_num = 5, show = True, lambdas = False)
eff_score_exp5_2021_col = bar_plot(data = exp5_2021_col, Institution_ID = 2, year = 2021, exp_num = 5, show = True)
eff_score_exp5_2023_col = bar_plot(data = exp5_2023_col, Institution_ID = 2, year = 2023, exp_num = 5)
